# %% [markdown]
# # Import The Dependencies

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11956\3449215735.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Data collection and preprocessing

# %%
# Loading the data from csv file from pandas Dataframe
df=pd.read_csv("C:/Users/Dell/Documents/T.Y.C.S NOTES/Mini project/ds task/banks file.csv")

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# inspecting the first 5 rows of a dataframe
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
# inspecting the last 5 rows of a dataframe
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
# checking the no of rows and columns 
df.shape
# Out:
# (11162, 17)

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
# getting some information about this dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
# checking the no of missing values 
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
# getting overall statistics about the dataset
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# # Visualization

# %% [markdown]
# # Univariates analysis of age, martial status, Job, Education process:

# %%
# distribution of age 
plt.figure(figsize=(6,6))
sns.distplot(df['age'])
plt.title('Distribution of age')
plt.show()

# %%
# Marital column
plt.figure(figsize=(6,6))
ax=sns.countplot(x='marital', data=df)
plt.title('Marital Status')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
# Job column
plt.figure(figsize=(14,6))
ax=sns.countplot(x='job', data=df)
plt.title('Job')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
plt.figure(figsize=(7,8))
labels=['Secondary','Tertiary','Primary','Unknown']
size=df['education'].value_counts()
explode=[0,0.1,0.1,0.1]
plt.pie(size,labels=labels,explode=explode,autopct='%.2f%%',shadow=True)
plt.legend(labels,loc=1,title='Education Percentage')
plt.show()

# %% [markdown]
# # Univariates analysis of default, housing Loan, (Y):

# %%
plt.figure(figsize=(7,7))
labels=['no','yes']
size=df['default'].value_counts()
explode=[0.1,0.4]
plt.pie(size,labels=labels,explode=explode,autopct='%.2f%%',shadow=True)
plt.legend(labels,loc=0,title='Percentage of credit default')
plt.show()

# %%
plt.figure(figsize=(7,7))
labels=['no','yes']
size=df['housing'].value_counts()
explode=[0.1,0]
plt.pie(size,labels=labels,explode=explode,autopct='%.2f%%',shadow=True)
plt.legend(labels,loc=1,title='Percentage of Housing Loan')
plt.show()

# %%
plt.figure(figsize=(7,7))
labels=['no','yes']
size=df['loan'].value_counts()
explode=[0.1,0]
plt.pie(size,labels=labels,explode=explode,autopct='%.2f%%',shadow=True)
plt.legend(labels,loc=1,title='Percentage of Personal Loan')
plt.show()

# %% [markdown]
# # Balance (Univariate)

# %%
# distribution of balance
plt.figure(figsize=(6,4))
sns.distplot(df['balance'])
plt.title('Distribution of Balance')
plt.show()

# %%
# Mode of contact
plt.figure(figsize=(6,6))
ax=sns.countplot(x='contact', data=df)
plt.title('Mode of Contact')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
# Month Name
plt.figure(figsize=(14,6))
ax=sns.countplot(x='month', data=df)
plt.title('Month Name')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %% [markdown]
# # Duration (Univariate)

# %%
# distribution of balance
plt.figure(figsize=(8,4))
sns.distplot(df['duration'])
plt.title('Distribution of Duartion')
plt.show()

# %% [markdown]
# # Campaign (Univariate)

# %%
# distribution of campaign
plt.figure(figsize=(8,4))
sns.distplot(df['campaign'])
plt.title('Distribution of Campaign')
plt.show()

# %%
# distribution of pdays
plt.figure(figsize=(8,4))
sns.distplot(df['pdays'])
plt.title('Distribution of Pdays')
plt.show()

# %%
# distribution of previous
plt.figure(figsize=(8,4))
sns.distplot(df['previous'])
plt.title('Distribution of Previous')
plt.show()

# %%
# previous Outcome
plt.figure(figsize=(6,6))
ax=sns.countplot(x='poutcome', data=df)
plt.title('Previous Outcome')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
# Age distribution by clients
plt.figure(figsize=(14,6))
sns.boxplot(df, x="job", y="age")
# Out:
# <Axes: xlabel='job', ylabel='age'>

# %%
# Age distribution by clients
plt.figure(figsize=(16,4))
sns.boxplot(df, x="job", y="age")
# Out:
# <Axes: xlabel='job', ylabel='age'>

# %%
# Drop duration columns 
df = df.drop('duration',axis=1)

# %%
# shape of dataset
print('Shape of dataset:',df.shape)
# Out:
# Shape of dataset: (11162, 16)

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  campaign  pdays  previous poutcome deposit
# 0    5   may         1     -1         0  unknown     yes
# 1    5   may         1     -1         0  unknown     yes
# 2    5   may         1     -1         0  unknown     yes
# 3    5   may         1     -1         0  unknown     yes
# 4    5   may         2     -1         0  unknown     yes

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'campaign', 'pdays', 'previous',
#        'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# # Observation
# 1. There are 16 features
# 2. The following Features are there in the dataset :
#   age, job, marital, education, default, balance,housing, loan, contact, day, month, campaign, pdays,previous , poutcome, y

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %% [markdown]
# # Observation
# 1. Numerical Data : age, balance,day,campaign,pdays,previous ,

# %%
# standardization of dataset 

from sklearn.preprocessing import StandardScaler

# copying the orignal dataframe to df_numerical
df_num = df.copy()

scaler = StandardScaler()
num_cols = [ 'age', 'balance','day','campaign','pdays','previous']
df_num[num_cols] = scaler.fit_transform(df_num[num_cols])
df_num = df_num.drop(['job', 'marital', 'education','default','housing','loan','contact','month','poutcome'],axis=1)
df_num.head()
# Out:
#         age   balance       day  campaign     pdays  previous deposit
# 0  1.491505  0.252525 -1.265746 -0.554168 -0.481184  -0.36326     yes
# 1  1.239676 -0.459974 -1.265746 -0.554168 -0.481184  -0.36326     yes
# 2 -0.019470 -0.080160 -1.265746 -0.554168 -0.481184  -0.36326     yes
# 3  1.155733  0.293762 -1.265746 -0.554168 -0.481184  -0.36326     yes
# 4  1.071790 -0.416876 -1.265746 -0.186785 -0.481184  -0.36326     yes

# %% [markdown]
# # The result in our training data is 36168 and testing data is 9043 .

# %% [markdown]
# # Model Building

# %%
# function to evaluate and calculate Accuracy, Precision, Recall, F1-score & Kappa Score
def evaluate_model(model, x_test, y_test):
    from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score,roc_curve, roc_auc_score, confusion_matrix
    import seaborn as sns
    import numpy as np
    
    # predict Test Data
    y_pred = model.predict(x_test)
    
    # calculate Accuracy, Precision, Recall, F1-score & Kappa Score
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    kappa = cohen_kappa_score(y_test, y_pred)
    
    # calculate area under curve (AUC)
    y_pred_proba = model.predict_proba(x_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    auc = roc_auc_score(y_test, y_pred_proba)
    
    # Display Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # visualization of a confusion matrix
    sns.heatmap(cm / np.sum(cm), annot=True, fmt='.2%', cmap='Blues')
    
    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1, 'kappa': kappa,
            'fpr': fpr, 'tpr': tpr, 'auc': auc, 'cm': cm}
